# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## 판다스 데이터 프레임 만들어서 작성
#
# pandas를 이용해서 데이터 프레임 작성하기

# %%
a = pandas.DataFrame(np.random.rand(4,5), columns=list('abcde'))

# 데이터프레임 작성(x,y 행렬, 각 행렬 이름)

# %%
a_array = a.values

# %%
plt.plot(a, a**2, label='pandas')

# %% [markdown]
# ## 1. 단순한 점 찍기 ##
#
# x,y 좌표를 array로 해서 미분 불가능한 선들을 좌표평면에 나타내기

# %%
plt.plot([4,2,1,3], [8,1,7,6], label="test1")
plt.legend()

# %% [markdown]
# ## 2. 1차, 2차, 3차 방정식 표현하기
#
# 1. Object Oriented Method
# 2. Plot

# %% [markdown]
# - Object Oriented Interface
#
# ax라는 오브젝트에 모든정보를 담는다.

# %%
fig, ax = plt.subplots()
x = np.linspace(-2,2,100)
ax.plot(x, x, label="linear")
ax.plot(x, x**2, label="quadratic")
ax.plot(x, x**3, label="cubic")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Equation")
plt.legend()

# %% [markdown]
# - Pyplot style
#
# plt에 그냥 때려 박는다. 다음에 사용 불가능

# %%
plt.plot(x, x, label="linear")
plt.plot(x, x**2, label="quadratic")
plt.plot(x, x**3, label="cubic")
plt.legend()
plt.title("Equation")
plt.show()

# %% [markdown]
# ## 3. 함수형 Plot

# %%
def my_plotter(ax, data1, data2, param_dict) :
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4,100)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
my_plotter(ax1, data1, data2, {'marker': 'x', 'color' : 'r'})
my_plotter(ax2, data3, data4, {'marker': 'v', 'color' : 'b'})
