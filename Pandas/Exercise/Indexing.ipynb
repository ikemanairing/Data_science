# %%
import pandas as pd

# %% [markdown]
# # Indexing exercises

# %% [markdown]
# 인덱싱을 잘해야 DataFrame이 예쁘다

# %%
pd.read_csv('dataset\student_feedback.csv')
# Out:
#       Unnamed: 0  Student ID  Well versed with the subject  \
# 0              0         340                             5
# 1              1         253                             6
# 2              2         680                             7
# 3              3         806                             9
# 4              4         632                             8
# ...          ...         ...                           ...
# 996          996          55                             8
# 997          997         913                             5
# 998          998         199                             9
# 999          999         539                            10
# 1000        1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# ...

# %%
# index col을 새로 만들지 않고 Unnamed:0 col을 그냥 index col로 쓰기

df = pd.read_csv('dataset\student_feedback.csv', index_col=0)

# %%
df
# Out:
#       Student ID  Well versed with the subject  \
# 0            340                             5
# 1            253                             6
# 2            680                             7
# 3            806                             9
# 4            632                             8
# ...          ...                           ...
# 996           55                             8
# 997          913                             5
# 998          199                             9
# 999          539                            10
# 1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# ...

# %%
df.rename(columns=hindex_col, inplace=True, errors='raise')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\LEGION~1\AppData\Local\Temp/ipykernel_28268/1081886538.py in <module>
# ----> 1 df.rename(columns=hindex_col, inplace=True, errors='raise')
#
# ~\miniconda3\envs\data_science\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5075         4  3  6
#    5076         """
# -> 5077         return super()._rename(
#    5078             mapper=mapper,
#    5079             index=index,
#
# ~\miniconda3\envs\data_science\lib\site-packages\pandas\core\generic.py in _rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1159                         if indexer[index] == -1
#    1160                     ]
# -> 1161                     raise KeyError(f"{missing_labels} not found in axis")
#    1162
# ...

# %%
hindex_col
# Out:
# 0                     학생 ID
# 1              주제를 잘 파악한 학생
# 2    개념을 이해할 수 있도록 설명할 수 있음
# 3            프레젠테이션을 이용한 학생
# 4                   과제의 난이도
# 5                 과제를 기꺼이 품
# 6                   과정을 계획함
# 7             주제를 넘는 과제를 제공
# 8                       관련성
# dtype: object

# %%
df
# Out:
#       Student ID  Well versed with the subject  \
# 0            340                             5
# 1            253                             6
# 2            680                             7
# 3            806                             9
# 4            632                             8
# ...          ...                           ...
# 996           55                             8
# 997          913                             5
# 998          199                             9
# 999          539                            10
# 1000         759                             7
#
#       Explains concepts in an understandable way  Use of presentations  \
# 0                                              2                     7
# 1                                              5                     8
# 2                                              7                     6
# 3                                              6                     7
# ...

# %% [markdown]
# ## columns의 맨 첫줄 바꾸기

# %%
df.columns = hindex_col
df
# Out:
#       학생 ID  주제를 잘 파악한 학생  개념을 이해할 수 있도록 설명할 수 있음  프레젠테이션을 이용한 학생  과제의 난이도  \
# 0       340             5                       2               7        6
# 1       253             6                       5               8        6
# 2       680             7                       7               6        5
# 3       806             9                       6               7        1
# 4       632             8                      10               8        4
# ...     ...           ...                     ...             ...      ...
# 996      55             8                       7               6        2
# 997     913             5                       5               6        5
# 998     199             9                       5               8        3
# 999     539            10                       2               7        4
# 1000    759             7                       2               4        2
#
#       과제를 기꺼이 품  과정을 계획함  주제를 넘는 과제를 제공  관련성
# ...

# %%
df
# Out:
#       학생 ID  주제를 잘 파악한 학생  개념을 이해할 수 있도록 설명할 수 있음  프레젠테이션을 이용한 학생  과제의 난이도  \
# 0       340             5                       2               7        6
# 1       253             6                       5               8        6
# 2       680             7                       7               6        5
# 3       806             9                       6               7        1
# 4       632             8                      10               8        4
# ...     ...           ...                     ...             ...      ...
# 996      55             8                       7               6        2
# 997     913             5                       5               6        5
# 998     199             9                       5               8        3
# 999     539            10                       2               7        4
# 1000    759             7                       2               4        2
#
#       과제를 기꺼이 품  과정을 계획함  주제를 넘는 과제를 제공  관련성
# ...
